# %% [markdown]
# Connecting Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Importing necessary modules & dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Reading the dataset1: Raw_Skills_Dataset

# %%
data1 = pd.read_csv('/content/drive/MyDrive/data/Raw_Skills_Dataset.csv')

# %% [markdown]
# Get glimpse of that data

# %%
data1.head()
# Out:
#           RAW DATA
# 0         What ifs
# 1        seniority
# 2      familiarity
# 3  functionalities
# 4          Lambdas

# %% [markdown]
# Lets check whether there is missing values or not

# %%
data1.isnull().sum().sum()
# Out:
# 0

# %%
data1[data1['RAW DATA'] == 'DevOps']
# Out:
#       RAW DATA
# 597     DevOps
# 645     DevOps
# 7668    DevOps
# 7885    DevOps
# 7890    DevOps
# 8348    DevOps
# 8355    DevOps
# 9033    DevOps
# 9062    DevOps
# 9558    DevOps
# 9568    DevOps
# 10069   DevOps
# 10185   DevOps
# 10250   DevOps
# 10511   DevOps
# 10542   DevOps
# 10573   DevOps
# 10604   DevOps
# 10635   DevOps
# 10666   DevOps
# 10697   DevOps
# 10892   DevOps
# 12841   DevOps
# 14456   DevOps
# 16796   DevOps
# 17209   DevOps
# 17221   DevOps
# 18018   DevOps
# 18748   DevOps
# 18937   DevOps
# 20098   DevOps
# 20899   DevOps
# 21082   DevOps
# 21915   DevOps
# 23082   DevOps
# 23967   DevOps
# 24462   DevOps
# 24947   DevOps
# 25151   DevOps
# 25251   DevOps
# 28375   DevOps
# 28801   DevOps
# 29507   DevOps
# 31111   DevOps
# 31739   DevOps
# 33372   DevOps
# 33937   DevOps

# %% [markdown]
# Shape of the data

# %%
data1.shape
# Out:
# (34116, 1)

# %% [markdown]
# Descriptive statistics of data

# %%
data1.describe()
# Out:
#        RAW DATA
# count     34116
# unique    15677
# top      Python
# freq        272

# %% [markdown]
# Basic Information about the data

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34116 entries, 0 to 34115
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   RAW DATA  34116 non-null  object
# dtypes: object(1)
# memory usage: 266.7+ KB

# %% [markdown]
# Reading the dataset2: Example_Techical_skills

# %%
data2 = pd.read_csv('/content/drive/MyDrive/data/Example_Technical_Skills.csv')

# %% [markdown]
# Get glimpse of data

# %%
data2.head()
# Out:
#                        Technology Skills
# 0                    SAP Fiori Developer
# 1  Oracle Instance Management & Strategy
# 2           Boomi Master Data Management
# 3  Digital Manufacturing on Cloud ( DMC)
# 4                                 DevOps

# %% [markdown]
# Checking datatypes

# %%
data1.dtypes
# Out:
# RAW DATA    object
# dtype: object

# %%
data2.dtypes
# Out:
# Technology Skills    object
# dtype: object

# %% [markdown]
# Lowercasing the data

# %%
data1["RAW DATA"] = data1["RAW DATA"].str.lower()
data2["Technology Skills"] = data2["Technology Skills"].str.lower()

# %%
data1.head()
# Out:
#           RAW DATA
# 0         what ifs
# 1        seniority
# 2      familiarity
# 3  functionalities
# 4          lambdas

# %%
data2.head()
# Out:
#                        Technology Skills
# 0                    sap fiori developer
# 1  oracle instance management & strategy
# 2           boomi master data management
# 3  digital manufacturing on cloud ( dmc)
# 4                                 devops

# %% [markdown]
# Now our Final Task is we have to remove those skills that are not available in our Technology Skills

# %%
val = data2['Technology Skills'].values

# %%
 val = list(val)

# %%
data1 = data1[data1['RAW DATA'].isin(val)]

# %%
data1.head()
# Out:
#     RAW DATA
# 62     mysql
# 111   github
# 154   github
# 353     scss
# 354    mysql

# %%
data1 = data1.reset_index()

# %%
data1.head()
# Out:
#    index RAW DATA
# 0     62    mysql
# 1    111   github
# 2    154   github
# 3    353     scss
# 4    354    mysql

# %%
data1.drop('index',axis=1,inplace=True)

# %% [markdown]
# So my final dataset is

# %%
data1.head()
# Out:
#   RAW DATA
# 0    mysql
# 1   github
# 2   github
# 3     scss
# 4    mysql

# %%
data1.columns = ['Final Data']

# %%
data1.head()
# Out:
#   Final Data
# 0      mysql
# 1     github
# 2     github
# 3       scss
# 4      mysql
